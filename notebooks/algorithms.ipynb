# %% [markdown]
# ## Learning algorithms

# %% [markdown]
# #### Implement DPO

# %%
def dpo_loss(log_probs: list, preferred:list):
	"""
	log_probs = log probabilities of tokens of both the preferred and unpreferred completions
	preferred = which of the 2 completions was preferred

	Implementing Bradley Terry preference loss for DPO
	"""
	
	
	pass

# %% [markdown]
# #### Implement GRPO

# %% [markdown]
# RL algorithms

# %% [markdown]
# Implement LoRA
